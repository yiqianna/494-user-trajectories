# %%
import pandas as pd

df = pd.read_csv("notes_data.tsv", sep="\t")
len(df)
# Out:
# /var/folders/12/m5q_z2nj5dn8xfh_ywr753sr0000gn/T/ipykernel_68909/2543384809.py:3: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("notes_data.tsv", sep="\t")
# 2350469
