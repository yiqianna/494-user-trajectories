# %%
import pandas as pd

path = "../../data/local/notes-00000.tsv"

df = pd.read_csv(path, sep="\t")

print("Total number of records:", len(df))
# Out:
# /var/folders/6t/36lllv95057d689vhyb7ltr80000gn/T/ipykernel_1605/4098841340.py:5: DtypeWarning: Columns (0: believable, 1: harmful, 2: validationDifficulty) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep="\t")
# Total number of records: 2350469
