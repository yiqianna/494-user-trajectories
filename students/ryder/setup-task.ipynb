# %%
import pandas as pd

# %%
filepath = "~/documents/github/494-user-trajectories/data/notes-00000.tsv"
notes = pd.read_csv(filepath, sep='\t')
print(len(notes))
# Out:
# /var/folders/14/04j_x_597gg_sc6gcvkrz1wr0000gp/T/ipykernel_59958/2002725596.py:2: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   notes = pd.read_csv(filepath, sep='\t')
# 2332168
