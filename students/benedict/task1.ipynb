# %%
import pandas as pd

path = "C:\\Users\\wongb\\Downloads\\notes-00000.tsv"

df = pd.read_csv(path, sep='\t')

print(len(df))
# Out:
# C:\Users\wongb\AppData\Local\Temp\ipykernel_23776\1017575904.py:5: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep='\t')
# 2362561

# %%
python -m git_filter_repo --path students/benedict/z/.env --invert-paths
