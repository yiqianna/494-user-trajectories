# %%
import pandas as pd

# %%
pwd
# Out:
# '/home/jovyan/494-user-trajectories/students/srutiban'

# %%
cd ../../
# Out:
# /home/jovyan/494-user-trajectories

# %%
tweets = pd.read_csv("notes-00000.tsv", sep= '\t')
# Out:
# /tmp/ipykernel_377/4043768796.py:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   tweets = pd.read_csv("notes-00000.tsv", sep= '\t')

# %%
obs = len(tweets)

# %%
print(obs)
# Out:
# 2350469
