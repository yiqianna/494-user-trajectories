# %%
import pandas as pd

df = pd.read_csv("notes-00000.tsv", sep="\t")
len(df)
# Out:
# /var/folders/4f/r978p6_j3ks88kgvgxnh3hlm0000gn/T/ipykernel_746/3836642013.py:3: DtypeWarning: Columns (0: believable, 1: harmful, 2: validationDifficulty) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("notes-00000.tsv", sep="\t")
# 2350469
