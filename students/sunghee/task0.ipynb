# %%
import pandas as pd

df = pd.read_csv('../../../info494/notes-00000.tsv', sep='\t')
df.shape[0]
# Out:
# /var/folders/6x/px2c4wgd07122kszz5ljmxgw0000gn/T/ipykernel_84936/3662510088.py:3: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../../info494/notes-00000.tsv', sep='\t')
# 2332168
