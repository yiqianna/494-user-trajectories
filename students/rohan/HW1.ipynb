# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/rohansimha/Downloads/notes-00000.tsv', sep='\t')
# Out:
# /var/folders/zf/12jn0jkj34xgp9200ll_z8f40000gn/T/ipykernel_71260/3608646746.py:1: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/rohansimha/Downloads/notes-00000.tsv', sep='\t')

# %%
print(len(df))
# Out:
# 2350469
